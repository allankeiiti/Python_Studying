# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# PyLab = Numpy + Matplot
plt.scatter(np.arange(50), np.random.randn(50))
plt.show()

# %%
# Plot e Scatter
fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(np.random.randn(50), color = 'red')

ax2 = fig.add_subplot(1, 2, 2)
ax2.scatter(np.arange(50), np.random.randn(50))
plt.show()

# %%
# Plots diversos
_, ax = plt.subplots(2, 3)

ax[0, 0].scatter(np.arange(50), np.random.randn(50), color = 'red')
ax[0, 0].set_title('Scatter')
ax[0, 1].plot(np.random.randn(50), color = 'green', linestyle = '-')
ax[0, 1].set_title('Plot')
ax[0, 2].hist(np.random.randn(50))
ax[0, 2].set_title('Histograma')

plt.show()

# %%
# Controle dos eixos X e Y
fig, axes = plt.subplots(1, 3, figsize = (12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("Eixos com range padrão")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("Eixos menores")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("Eixos customizados");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-26b6562f352f> in <module>
#       2 fig, axes = plt.subplots(1, 3, figsize = (12, 4))
#       3
# ----> 4 axes[0].plot(x, x**2, x, x**3)
#       5 axes[0].set_title("Eixos com range padrão")
#       6
#
# NameError: name 'x' is not defined
